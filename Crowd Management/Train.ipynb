# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/drive/MyDrive/YOLO/yolov7/runs/detect/exp3/people_counterv0.v1i.yolov8.zip -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/train/labels/img_100_jpg.rf.3c42c138397bee46f56e91069d61d763.txt
#  extracting: /content/train/labels/img_100_jpg.rf.67eaac358440107c75f7e02b1adb4a39.txt
#  extracting: /content/train/labels/img_100_jpg.rf.c97ed29f8023da4e4c5c88cfaf1ec0d8.txt
#  extracting: /content/train/labels/img_100_jpg.rf.d4316fdbd268be1d3c2eb45c006c6397.txt
#  extracting: /content/train/labels/img_100_jpg.rf.ee11e334dfcfffaf3ba76df873e6e1f9.txt
#  extracting: /content/train/labels/img_1010_jpg.rf.09433d3e0fdf041ac3669925aa9202f0.txt
#  extracting: /content/train/labels/img_1010_jpg.rf.8f0859919b82b9f9b99aeaf61989a7ea.txt
#  extracting: /content/train/labels/img_1010_jpg.rf.bf440768daf5f2fc98f1bd41b72024ac.txt
#  extracting: /content/train/labels/img_1010_jpg.rf.cbf4403cb5709d3e75aa959af42a36ed.txt
#  extracting: /content/train/labels/img_1010_jpg.rf.e203eeedd14dddae01e2f3d840221e5f.txt
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 76.3MB/s]

# %%
model.train(data='/content/data.yaml', epochs = 50, batch=8, max_det=1000, visualize=True)
# Out:
# Ultralytics YOLOv8.1.9 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r /content/file.zip  /content/runs/
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-7-a359f97db9f3> in <cell line: 1>()
# ----> 1 get_ipython().system('zip -r /content/file.zip  /content/runs/')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...
