# %%
from ultralytics import YOLO

# %%
model = YOLO('best (1).pt')

# %%
from PIL import Image

# %%
import cv2
cap = cv2.VideoCapture('./Test-Images/production_id_4766165 (2160p).mp4')
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()
        annotated_frame = cv2.resize(annotated_frame, (640,480))
        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 14 peoples, 166.7ms
# Speed: 21.0ms preprocess, 166.7ms inference, 5.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 peoples, 191.1ms
# Speed: 7.0ms preprocess, 191.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 peoples, 126.1ms
# Speed: 5.0ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 191.0ms
# Speed: 4.0ms preprocess, 191.0ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 peoples, 123.1ms
# Speed: 5.0ms preprocess, 123.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 145.4ms
# Speed: 5.9ms preprocess, 145.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 108.2ms
# Speed: 3.4ms preprocess, 108.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 peoples, 166.8ms
# Speed: 4.0ms preprocess, 166.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 peoples, 225.2ms
# Speed: 5.0ms preprocess, 225.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 peoples, 106.8ms
# Speed: 4.0ms preprocess, 106.8ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 peoples, 171.3ms
# Speed: 7.1ms preprocess, 171.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 peoples, 77.1ms
# Speed: 2.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 peoples, 100.9ms
# Speed: 2.0ms preprocess, 100.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 peoples, 69.9ms
# Speed: 2.1ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 peoples, 66.0ms
# Speed: 1.9ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 peoples, 80.2ms
# Speed: 2.0ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 peoples, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 peoples, 72.4ms
# Speed: 2.9ms preprocess, 72.4ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 peoples, 68.4ms
# Speed: 1.9ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 peoples, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 peoples, 73.0ms
# Speed: 2.2ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 peoples, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 72.0ms
# Speed: 1.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 peoples, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 18 peoples, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 79.3ms
# Speed: 0.9ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 peoples, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 peoples, 65.2ms
# Speed: 2.0ms preprocess, 65.2ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 74.1ms
# Speed: 3.0ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 63.3ms
# Speed: 1.9ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 peoples, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 82.0ms
# Speed: 1.9ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 peoples, 74.0ms
# Speed: 2.4ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 peoples, 67.9ms
# Speed: 2.0ms preprocess, 67.9ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 peoples, 72.4ms
# Speed: 1.0ms preprocess, 72.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 peoples, 64.0ms
# Speed: 2.4ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 peoples, 153.7ms
# Speed: 1.9ms preprocess, 153.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 peoples, 138.8ms
# Speed: 3.0ms preprocess, 138.8ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 peoples, 235.5ms
# Speed: 6.0ms preprocess, 235.5ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 peoples, 189.1ms
# Speed: 6.0ms preprocess, 189.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       5 success, frame = cap.read()
#       7 if success:
#       8     # Run YOLOv8 inference on the frame
# ----> 9     results = model(frame)
#      11     # Visualize the results on the frame
#      12     annotated_frame = results[0].plot()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\model.py:101, in Model.__call__(self, source, stream, **kwargs)
#      99 def __call__(self, source=None, stream=False, **kwargs):
#     100     """Calls the 'predict' function with given arguments to perform object detection."""
# --> 101     return self.predict(source, stream, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\model.py:242, in Model.predict(self, source, stream, predictor, **kwargs)
#     240 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     241     self.predictor.set_prompts(prompts)
# --> 242 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\predictor.py:196, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     194     return self.stream_inference(source, model, *args, **kwargs)
#     195 else:
# --> 196     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\predictor.py:259, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     257 # Inference
#     258 with profilers[1]:
# --> 259     preds = self.inference(im, *args, **kwargs)
#     261 # Postprocess
#     262 with profilers[2]:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\predictor.py:135, in BasePredictor.inference(self, im, *args, **kwargs)
#     132 """Runs inference on a given image using the specified model and arguments."""
#     133 visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     134                            mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 135 return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\autobackend.py:347, in AutoBackend.forward(self, im, augment, visualize)
#     344     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     346 if self.pt or self.nn_module:  # PyTorch
# --> 347     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     348 elif self.jit:  # TorchScript
#     349     y = self.model(im)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\tasks.py:42, in BaseModel.forward(self, x, *args, **kwargs)
#      40 if isinstance(x, dict):  # for cases of training and validating while training.
#      41     return self.loss(x, *args, **kwargs)
# ---> 42 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\tasks.py:59, in BaseModel.predict(self, x, profile, visualize, augment)
#      57 if augment:
#      58     return self._predict_augment(x)
# ---> 59 return self._predict_once(x, profile, visualize)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\tasks.py:79, in BaseModel._predict_once(self, x, profile, visualize)
#      77 if profile:
#      78     self._profile_one_layer(m, x, dt)
# ---> 79 x = m(x)  # run
#      80 y.append(x if m.i in self.save else None)  # save output
#      81 if visualize:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\modules\head.py:46, in Detect.forward(self, x)
#      44 shape = x[0].shape  # BCHW
#      45 for i in range(self.nl):
# ---> 46     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      47 if self.training:
#      48     return x
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\modules\conv.py:40, in Conv.forward_fuse(self, x)
#      38 def forward_fuse(self, x):
#      39     """Perform transposed convolution of 2D data."""
# ---> 40     return self.act(self.conv(x))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
model.predict(source=r"C:\Users\PRATAP\Downloads\img.jpg",max_det=10000,show=True,show_labels=False )
# Out:
# image 1/1 C:\Users\PRATAP\Downloads\img.jpg: 448x640 205 peoples, 272.8ms
# Speed: 8.0ms preprocess, 272.8ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'people'}
#  orig_img: array([[[  6,  15,  29],
#          [  6,  15,  29],
#          [  6,  15,  29],
#          ...,
#          [116, 160, 224],
#          [119, 162, 229],
#          [117, 162, 229]],
#
#         [[  6,  15,  29],
#          [  6,  15,  29],
#          [  6,  15,  29],
#          ...,
#          [117, 161, 225],
#          [126, 169, 236],
#          [124, 169, 236]],
#
#         [[  6,  15,  29],
#          [  6,  15,  29],
#          [  6,  15,  29],
#          ...,
#          [109, 153, 217],
#          [116, 159, 226],
#          [114, 159, 226]],
#
#         ...,
#
#         [[ 26,  26,  20],
#          [  0,   2,   0],
#          [  6,   7,   3],
#          ...,
#          [ 28, 164, 242],
#          [ 14, 146, 229],
#          [ 12, 146, 230]],
#
#         [[ 51,  49,  41],
#          [  9,  10,   1],
#          [  7,   6,   2],
#          ...,
#          [ 58, 207, 255],
#          [ 51, 199, 255],
#          [ 51, 198, 255]],
#
#         [[ 71,  68,  60],
#          [ 17,  15,   7],
#          [  4,   1,   0],
#          ...,
#          [ 52, 211, 255],
#          [ 52, 210, 255],
#          [ 52, 210, 255]]], dtype=uint8)
#  orig_shape: (315, 474)
#  path: 'C:\\Users\\PRATAP\\Downloads\\img.jpg'
#  probs: None
#  save_dir: None
#  speed: {'preprocess': 8.008480072021484, 'inference': 272.794246673584, 'postprocess': 2.980470657348633}]
